# %% [markdown]
# # Statistics Advance Part 1
#
# 1. What is a random variable in probability theory?
# - In probability theory, a random variable is a variable that represents the possible outcomes of a random experiment. It assigns numerical values to those outcomes, allowing us to apply mathematical tools to analyze them.
#
# 2. What are the types of random variables?
# - In probability theory, random variables are categorized based on the type of values they can take. There are two main types:
#  - Discrete Random Variables
#  - Continuous Random Variables
#
# 3. What is the difference between discrete and continuous distributions?
# - The difference between discrete and continuous distributions lies in the type of values the random variable can take:
#
#  * Discrete Distributions
#
# Definition: A distribution where the random variable takes countable (often finite or countably infinite) values.
#
# Examples: Number of heads in coin tosses, number of students in a class, dice rolls.
#
# Probability Representation:
#
#  - Represented using a Probability Mass Function (PMF).
#
#  - Probability is assigned to individual values.
#
#   * Continuous Distributions
#
# Definition: A distribution where the random variable takes values from a continuous range (i.e., any value in an interval).
#
# Examples: Height of people, temperature, time taken to run a race.
#
# Probability Representation:
#
#  - Represented using a Probability Density Function (PDF).
#
#  - Probability of any single value is zero; instead, probabilities are for intervals.
#
# 4. What are probability distribution functions (PDF)?
# - Probability Distribution Functions (PDFs) are fundamental concepts in probability and statistics that describe how the values of a random variable are distributed.
#
# 5.  How do cumulative distribution functions (CDF) differ from probability distribution functions (PDF)?
# - Cumulative Distribution Functions (CDFs) and Probability Distribution Functions (PDFs) are both used to describe probability distributions, but they serve different purposes and provide different types of information.
#
#  - Probability Distribution Function (PDF)
#
# Used for: Continuous random variables.
#
# Definition: Describes the relative likelihood of a random variable taking on a specific value.
#
#    -  Cumulative Distribution Function (CDF)
#
# Used for: Both discrete and continuous random variables.
#
# Definition: Describes the probability that a random variable is less than or equal to a certain value.
#
# 6. What is a discrete uniform distribution?
# - A discrete uniform distribution is a type of probability distribution where each of the possible outcomes has an equal probability of occurring.
#
# 7.  What are the key properties of a Bernoulli distribution?
# - The Bernoulli distribution is a discrete probability distribution for a random variable with only two possible outcomes: success (usually coded as 1) and failure (coded as 0).
#
# Key Properties of a Bernoulli Distribution:
#  *  Support (Possible Values)
#  * Probability Mass Function (PMF)
#  * Mean (Expected Value)
#  * Variance
#  * Skewness
#  * Kurtosis (Excess)
#  * Entropy (Information Content)
#
# 8. What is the binomial distribution, and how is it used in probability?
# - The binomial distribution is a discrete probability distribution that models the number of successes in a fixed number of independent Bernoulli trials, each with the same probability of success.
#
# Binomial Probability Formula:
# 𝑃
# (
# 𝑋
# =
# 𝑘
# )
# =
# (
# 𝑛
# 𝑘
# )
# 𝑝
# 𝑘
# (
# 1
# −
# 𝑝
# )
# 𝑛
# −
# 𝑘
# P(X=k)=(
# k
# n
# ​
#  )p
# k
#  (1−p)
# n−k
#
# 9. What is the Poisson distribution and where is it applied?
# - The Poisson distribution is a discrete probability distribution that models the number of events occurring in a fixed interval of time or space, given that:
#
# The events occur independently, and
#
# The average rate (
# λ) of occurrence is constant.
#
# When to Use the Poisson Distribution:
#
# Use it when you're counting how many times something happens in a fixed time or space, such as:
#
# Number of phone calls received per hour.
#
# Number of emails received in a day.
#
# Number of customer arrivals at a store in an hour.
#
# Number of printing errors per page in a book.
#
# Number of accidents at a traffic intersection per week.
#
# 10.  What is a continuous uniform distribution?
# - The continuous uniform distribution is a probability distribution in which all values in a given range are equally likely to occur. It is defined over a continuous interval
# [a,b], and every value within this interval has the same probability density.
#
# 11. What are the characteristics of a normal distribution?
# - The normal distribution, also known as the Gaussian distribution, is one of the most important and widely used probability distributions in statistics. Here are its key characteristics:
#
# Key Characteristics of a Normal Distribution:
#
#  * Bell-Shaped Curve
#  * Mean = Median = Mode
#  * Symmetry
#  * Defined by Two Parameters
#  * Empirical Rule (68-95-99.7 Rule)
#  * Asymptotic Tails
#  * Unimodal
#  * Area Under the Curve = 1
#
# 12. What is the standard normal distribution, and why is it important?
# - The standard normal distribution is a special case of the normal distribution with:
#
# Mean (μ) = 0
#
# Standard deviation (σ) = 1
#
# It is a bell-shaped, symmetric probability distribution centered around zero.
#
# The variable in this distribution is typically denoted as Z, and it's often referred to as the Z-distribution.
#
#  * Universal Reference:
#
# Any normal distribution can be converted to a standard normal distribution using Z-score transformation:
#
# This allows comparison between different normal distributions.
#
# * Simplifies Calculations:
#
# Probabilities and percentiles are easier to compute using Z-tables (or software functions like norm.cdf()).
#
#  * Foundational for Hypothesis Testing:
#
# Many statistical tests (e.g., Z-test, confidence intervals) rely on the standard normal distribution.
#
#  * Critical in Central Limit Theorem (CLT):
#
# The CLT states that the sampling distribution of the sample mean approaches a standard normal distribution as sample size increases, regardless of the population’s original distribution.
#
#  * Basis for Many Models:
#
# Used in machine learning, risk assessment, quality control, etc., as a base for modeling and inference.
#
# 13.  What is the Central Limit Theorem (CLT), and why is it critical in statistics?
# - The Central Limit Theorem states that:
#   When you take sufficiently large random samples from any population (with a finite mean and variance), the distribution of the sample means will approach a normal distribution—regardless of the original population's distribution.
#
#    * Why is the CLT Important?
#
#  * Foundation of Inferential Statistics
#
# It justifies why we can use the normal distribution to approximate the behavior of sample means—even when the population distribution is not normal.
#
#  * Confidence Intervals & Hypothesis Testing
#
# CLT allows us to make probabilistic statements (e.g., margins of error, p-values) about population parameters using sample data.
#
#  * Simplifies Analysis
#
# Many statistical procedures (t-tests, ANOVA, regression) rely on normality. CLT allows these methods to work well even when the raw data isn't normally distributed—as long as the sample size is large enough.
#
#  * Real-World Applicability
#
# CLT applies in quality control, polling, finance, medicine, and machine learning—anywhere sampling and averages are involved.
#
# 14.  How does the Central Limit Theorem relate to the normal distribution?
# - The Central Limit Theorem (CLT) is fundamentally connected to the normal distribution and plays a crucial role in statistics.
#
# Connection to the Normal Distribution
#
#  - Shape of the Sampling Distribution:
#
# No matter what the original population distribution is (skewed, uniform, exponential, etc.), the distribution of the sample means will approximate a normal distribution as the sample size (n) increases, typically n ≥ 30 is sufficient.
#
#  - Parameters of the Sampling Distribution:
#
# If
# 𝜇
# μ is the population mean and
# 𝜎
# σ is the standard deviation:
#
# Mean of sample means =
# 𝜇
# μ
#
# Standard deviation of sample means =
# 𝜎
# 𝑛
# n
# ​
#
# σ
# ​
#   (called the standard error)
#
#  - Practical Implication:
#
# It allows us to use the normal distribution to make inferences (confidence intervals, hypothesis tests) about population parameters even when the population itself is not normal.
#
# 15. What is the application of Z statistics in hypothesis testing?
# - The Z-statistic (or Z-score) is used in hypothesis testing when you want to determine how far a sample statistic is from the population parameter, measured in standard deviations. It is particularly useful when the population standard deviation is known and either:
#
# The sample size is large (typically
# 𝑛
# ≥
# 30
# n≥30), or
#
# The population is normally distributed.
#
# 16. How do you calculate a Z-score, and what does it represent?
# - The Z-score (or standard score) measures how many standard deviations a data point is from the mean.
#
# -  Z-Score Formula
# For a single data point
# 𝑥
# x:
#
# 𝑍
# =
# 𝑥
# −
# 𝜇
# 𝜎
# Z=
# σ
# x−μ
# ​
#
# Where:
#
# 𝑥
# x = individual data value
#
# 𝜇
# μ = population mean
#
# 𝜎
# σ = population standard deviation
#
# If you're working with a sample, use the sample mean
# 𝑥
# ˉ
# x
# ˉ
#   and sample standard deviation
# 𝑠
# s:
#
# 𝑍
# =
# 𝑥
# −
# 𝑥
# ˉ
# 𝑠
# Z=
# s
# x−
# x
# ˉ
#
# ​
#
# 17. What are point estimates and interval estimates in statistics?
# - In statistics, point estimates and interval estimates are two fundamental ways to estimate unknown population parameters based on sample data.
#
#  - Point Estimate
#
# A point estimate is a single value that serves as an approximation of an unknown population parameter.
#
# Example:
# If you want to estimate the population mean (μ), you might use the sample mean (
# 𝑥
# ˉ
# x
# ˉ
#  ) as the point estimate.
#
#  - Interval Estimate
#
# An interval estimate gives a range of values within which the population parameter is expected to lie, along with a certain confidence level.
#
# Example:
# A 95% confidence interval for the population mean might be:
# 𝑥
# ˉ
# ±
# 𝑧
# ∗
# ⋅
# 𝜎
# 𝑛
# x
# ˉ
#  ±z
# ∗
#  ⋅
# n
# ​
#
# σ
# ​
#
# This means we are 95% confident that the true mean lies within that range.
#
# 18. What is the significance of confidence intervals in statistical analysis?
# - Significance of Confidence Intervals in Statistical Analysis
# Confidence intervals (CIs) play a crucial role in understanding and interpreting data in statistics. Here’s why they are important:
#
# ✅ 1. Quantify Uncertainty
# Confidence intervals express the degree of uncertainty or margin of error associated with a point estimate (like a sample mean or proportion).
#
# Example:
# Saying “the mean is 100” is less informative than saying “the mean is between 95 and 105 with 95% confidence.”
#
# ✅ 2. Make Informed Decisions
# CIs help researchers and decision-makers understand the range of plausible values for a population parameter, rather than relying on a single estimate.
#
# In business, medicine, policy, etc., knowing the likely range helps in risk assessment and strategic planning.
#
# ✅ 3. Assess Statistical Significance
# Confidence intervals are often used to determine whether an effect is statistically significant.
#
# Example:
# If a 95% confidence interval for the difference in means does not include 0, the difference is statistically significant at the 5% level.
#
# ✅ 4. Support Hypothesis Testing
# Instead of just relying on a p-value, confidence intervals show the actual range of values consistent with the data, making hypothesis testing more transparent.
#
# ✅ 5. Communicate Results Clearly
# CIs provide an intuitive way to communicate results to a non-technical audience.
#
# “We’re 95% confident that the true proportion is between 48% and 52%” is easier to understand than a p-value or test statistic.
#
# ✅ 6. Adapt to Sample Size
# Confidence intervals naturally adjust based on the size and variability of the sample:
#
# Larger sample size → Narrower interval → More precision
#
# Smaller sample size → Wider interval → Less precision
#
# 19. What is the relationship between a Z-score and a confidence interval?
# - The Z-score (or Z-value) and the confidence interval are closely related concepts in statistics—especially when estimating population parameters using a normal distribution or the Central Limit Theorem.
#
# 20. How are Z-scores used to compare different distributions?
# - Why Use Z-scores to Compare Different Distributions?
# Different datasets may be:
#
# Measured on different scales (e.g., centimeters vs inches)
#
# Have different units, means, and variances
#
# Z-scores standardize the values, allowing direct comparison on a common scale — the standard normal distribution, which has:
#
# Mean = 0
#
# Standard deviation = 1
#
# 21.  What are the assumptions for applying the Central Limit Theorem?
# - Key Assumptions of the Central Limit Theorem:
#
#  - Random Sampling:
# The data should be collected using a random process. Each observation must be independent and randomly selected from the population.
#
#  - Independence:
# Observations must be independent of each other.
#
# If sampling without replacement, the sample size should be less than 10% of the population to approximate independence (10% condition).
#
#  - Sample Size (n):
# For non-normal populations, the sample size must be sufficiently large.
#
# - A common rule of thumb is:
#
# 𝑛
# ≥
# 30
# n≥30 for skewed or unknown distributions.
#
# Smaller
# 𝑛
# n may be acceptable if the population is approximately normal.
#
# - Finite Variance:
# The population should have a finite mean and variance.
#
# CLT does not apply if variance is infinite or undefined.
#
# 22. What is the concept of expected value in a probability distribution?
# - The expected value in a probability distribution is a fundamental concept in probability and statistics. It represents the long-run average outcome or mean value of a random variable over many repeated trials of an experiment.
#
# 23. How does a probability distribution relate to the expected outcome of a random variable?
# - A probability distribution directly determines the expected outcome of a random variable, because it defines the likelihood of each possible value the variable can take. The expected value (or mean) is calculated using the values of the random variable and the probabilities assigned to them in the distribution.
